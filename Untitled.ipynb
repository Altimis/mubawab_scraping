# %%
import pandas as %pd

# %%
df = pd.read_excel(r'codes-postaux-quartiers-2018.xlsx')
df[df["VILLE"]=="CASABLANCA"]
# Out:
#            VILLE                       QUARTIER  NOUVEAU CODE POSTAL
# 1286  CASABLANCA  QUARTIER SIDI BELYOUT HORLOGE                20000
# 1287  CASABLANCA                  DERB  ALGBBAS                20010
# 1288  CASABLANCA                DERB  BOUCHAIB                 20010
# 1289  CASABLANCA                 DERB  EL GARAA                20010
# 1290  CASABLANCA                DERB  EL MEDRA                 20010
# ...          ...                            ...                  ...
# 2883  CASABLANCA        QUARTIER S.OTHMANE JDID                20700
# 2884  CASABLANCA             QUARTIER SALMIA II                20700
# 2885  CASABLANCA   QUARTIER SALMIA II FERREILLE                20700
# 2886  CASABLANCA         QUARTIER SIDI OTHMANE                 20700
# 2887  CASABLANCA        QUARTIER SIDI OTHMANE 1                20700
#
# [1602 rows x 3 columns]

# %%
import re
regex = f"(\d+)-(\d+)(pages)"
text = "vz rgrbreregr reb dfbe 8682 vs5 5 efe 1-3 pages ese  trt 56546 "
print(re.findall(regex, text.strip().replace(" ", ""))[0][1])
# Out:
# 3

# %%
text.strip()
# Out:
# '1-3pages'

# %%
a = ["a\n", "b\n"]
for aa in a:
    aa = aa.replace("\n","")
print(a)
# Out:
# ['a\n', 'b\n']

# %%
pip install http_request_randomizer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from http_request_randomizer.requests.proxy.requestProxy import RequestProxy
req_proxy = RequestProxy()  # you may get different number of proxy when you run this at each time
proxies = req_proxy.get_proxy_list()
# Out:
# 2022-01-02 22:59:38,761 http_request_randomizer.requests.useragent.userAgent INFO     Using local file for user agents: C:\Users\yassine\anaconda3\lib\site-packages\http_request_randomizer\requests\proxy\../data/user_agents.txt
# 2022-01-02 22:59:38,765 root   DEBUG    === Initialized Proxy Parsers ===
# 2022-01-02 22:59:38,766 root   DEBUG    	 FreeProxy parser of 'http://free-proxy-list.net' with required bandwidth: '150' KBs
# 2022-01-02 22:59:38,768 root   DEBUG    	 PremProxy parser of 'https://premproxy.com/list/' with required bandwidth: '150' KBs
# 2022-01-02 22:59:38,769 root   DEBUG    	 SslProxy parser of 'https://www.sslproxies.org' with required bandwidth: '150' KBs
# 2022-01-02 22:59:38,770 root   DEBUG    =================================
# 2022-01-02 22:59:39,565 http_request_randomizer.requests.parsers.FreeProxyParser ERROR    Provider FreeProxy failed with Attribute error: 'NoneType' object has no attribute 'find'
# ...

# %%
a = {"a":[1,2,3], "b":[4,5,6]}

# %%
import pandas as pd
pd.DataFrame(a)
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.read_csv("Mubawab_data_casablanca.csv")
df
# Out:
#      Unnamed: 0                 date arrondissement  \
# 0             0           04/01/2022      Bernoussi
# 1             1           04/01/2022      Bernoussi
# 2             2           04/01/2022      Bernoussi
# 3             3           04/01/2022      Bernoussi
# 4             4  2021-12-31 00:00:00      Bernoussi
# ..          ...                  ...            ...
# 674         674  2021-07-08 00:00:00  Roches-Noires
# 675         675  2021-07-08 00:00:00  Roches-Noires
# 676         676  2021-07-08 00:00:00  Roches-Noires
# 677         677  2021-07-08 00:00:00  Roches-Noires
# 678         678  2021-07-08 00:00:00  Roches-Noires
#
#                                             offer link  \
# 0    https://www.mubawab.ma/fr/pa/7284467/apartemen...
# 1    https://www.mubawab.ma/fr/pa/7276884/studio-de...
# 2    https://www.mubawab.ma/fr/pa/7276873/apartemen...
# 3    https://www.mubawab.ma/fr/pa/7276874/apartemen...
# 4    https://www.mubawab.ma/fr/pa/7126484/apparteme...
# ...

# %%
text = "Publié il y a plus de 6 jour"
regex = f"(\d)(jour|jours)"
re.findall(regex, text.strip().replace(" ", ""))[0][0]
# Out:
# '6'

# %%
import datetime
today = datetime.date.today().strftime("%d/%m/%Y")
datetime.datetime.strptime(today,"%d/%m/%Y")+datetime.timedelta(days=10)
# Out:
# datetime.datetime(2022, 1, 14, 0, 0)

# %%
import pickle

# %%
a = {"a": 0, "b": 1}
for k, v in a.items():
    print(k, v)
# Out:
# a 0
# b 1

# %%
a_file = open("data_arrondissement.pkl", "rb")
data = pickle.load(a_file)
data
# Out:
# {'Al-Fida': {'links': ['https://www.mubawab.ma/fr/a/7333754/vente-d-un-bel-appartement-%C3%A0-hay-alamal-surface-totale-50-m%C2%B2-prestation-de-conciergerie',
#    'https://www.mubawab.ma/fr/a/7330323/maison-r3-sur-terrain-de-60m%C2%B2-%C3%A0-sidi-m%C3%A2arouf-4',
#    'https://www.mubawab.ma/fr/a/7308672/bel-appt-au-centre-de-2-mars-casa',
#    'https://www.mubawab.ma/fr/a/7300433/bonne-affaire-%C3%A0-vendre-%C3%A0-derb-kor%C3%A9a',
#    'https://www.mubawab.ma/fr/a/7327219/appartement-dans-un-excellent-emplacement',
#    'https://www.mubawab.ma/fr/a/7322438/villa-%C3%A0-vendre',
#    'https://www.mubawab.ma/fr/a/7317118/vente-d-un-bel-appartement-%C3%A0-hay-alamal-2-grandes-pi%C3%A8ces-garage',
#    'https://www.mubawab.ma/fr/a/7313323/appartement-en-vente-%C3%A0-hay-alamal-surface-de-92-m%C2%B2-syst%C3%A8me-de-parabole-et-r%C3%A9sidence-s%C3%A9curis%C3%A9e',
#    'https://www.mubawab.ma/fr/p/2563/zenata-tower',
# ...

# %%
for arr, d in data.items():
    for link, date in zip(d['links'], d['dates']):
        print("arr: ", arr)
        print("link: ", link)
        print("date: ", date)
        print("#########")
# Out:
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7333754/vente-d-un-bel-appartement-%C3%A0-hay-alamal-surface-totale-50-m%C2%B2-prestation-de-conciergerie
# date:  2022-01-05 00:00:00
# #########
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7330323/maison-r3-sur-terrain-de-60m%C2%B2-%C3%A0-sidi-m%C3%A2arouf-4
# date:  2022-01-11 00:00:00
# #########
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7308672/bel-appt-au-centre-de-2-mars-casa
# date:  2022-01-11 00:00:00
# #########
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7300433/bonne-affaire-%C3%A0-vendre-%C3%A0-derb-kor%C3%A9a
# date:  2022-01-11 00:00:00
# #########
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7327219/appartement-dans-un-excellent-emplacement
# date:  2022-01-11 00:00:00
# #########
# arr:  Al-Fida
# link:  https://www.mubawab.ma/fr/a/7322438/villa-%C3%A0-vendre
# date:  2022-01-18 00:00:00
# #########
# arr:  Al-Fida
# ...

# %%
import pickle
a_file = open("data_arrondissement_louer_anfa_maarif.pkl", "rb")
data = pickle.load(a_file)

# %%
data
# Out:
# {'Al-Fida': {},
#  'Anfa': {'links': ['https://www.mubawab.ma/fr/a/7320595/tr%C3%A8s-bel-appartement-meubl%C3%A9-%C3%A0-louer-%C3%A0-ain-diab',
#    'https://www.mubawab.ma/fr/a/7335655/superbe-appartement-front-mer-%C3%A0-louer-%C3%A0-ain-diab',
#    'https://www.mubawab.ma/fr/a/7321669/appartement-raffin%C3%A9-et-sobre-%C3%A0-louer-%C3%A0-ain-diab',
#    'https://www.mubawab.ma/fr/a/7319503/somptueux-appartement-en-location-%C3%A0-racine',
#    'https://www.mubawab.ma/fr/a/7262620/grande-villa-moderne-refaite-au-quartier-el-manar',
#    'https://www.mubawab.ma/fr/a/7251192/racine-location-appartement-meubl%C3%A9-moderne',
#    'https://www.mubawab.ma/fr/a/7332539/location-appartement-moderne-quartier-racine',
#    'https://www.mubawab.ma/fr/a/7336057/magnifique-villa-%C3%A0-louer-%C3%A0-ain-diab-extension-5-pi%C3%A8ces-confortables-piscine-et-chemin%C3%A9e',
#    'https://www.mubawab.ma/fr/p/2562/kamal-park-center',
# ...

# %%
import re
a = "ac 5216"
int(re.findall(f'\d+', a)[0])
# Out:
# 5216

# %%
import dateparser
print(dateparser.parse("09 Août", languages = ['fr'], date_formats=['%d %m']))
# Out:
# None

# %%
print(re.match(f'\d+\D\d+', "15:25"))
# Out:
# <re.Match object; span=(0, 5), match='15:25'>

# %%
import datetime
today = datetime.date.today().strftime("%d/%m/%Y")
day = today
