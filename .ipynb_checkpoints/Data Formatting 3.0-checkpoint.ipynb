# %%
import pandas as pd
import itertools
from datetime import datetime



df = pd.read_csv('Mubawab_data_casablanca.csv',index_col=[0])

# %%
def string_to_date(string):
    
    if len(string)==10:
        return datetime.strptime(string, "%d/%m/%Y")
    
    else :
        string = string[:10]
        return datetime.strptime(string, "%Y-%m-%d")
    


def keep_only_digits(string):
    if string is not None:
    
        return(''.join(filter(str.isdigit,string)))
    
    else:
        return None




def price_string_to_float(string):
    
    if isinstance(string, str):
        
        string = string.lower()
        
        if 'dh' in string:
        
            return(float(keep_only_digits(string)))
        
        elif 'eur' in string:
            
            return(float(keep_only_digits(string))*10.5)
        
        else:
            
            return(float(keep_only_digits(string))*9)
        



def get_X_Y(string, axe='X'):
    
    if string:
    
        dic_pos = eval(string)

        if axe=='X':

            return dic_pos['x']
        else:
            return dic_pos['y']
        
def get_type_from_link(link):
    'apt'
    link = link.lower()
    
    #combinaison_app = ['app','apartement','apart','apt','aprt']
    
    
        
    
    if ('app'  in link) or ('apartement' in link) or ('apart' in link) or ('apt' in link) or ('aprt' in link): #bricoul a modifi
        return 'A'
    elif 'maison' in link:
        return 'M'
    elif 'villa' in link:
        return 'V'
    elif 'riad' in link:
        return 'R'
    
    elif 'immeuble' in link:
        return 'I'
    
    elif 'studio' in link:
        return 'S'
    elif 'duplex' in link:
        return 'D'
    else:
        return 'Jesspa'

# %%
def eval_2(string):

    if isinstance(string,str):
        return eval(string)
    else:
        return None

def index_by_word(string,L):
    
    LL = [string in w for w in L]
    
    if sum(LL)==1:
        return(LL.index(True))
    
    elif sum(LL)==0:
        return None
    
    else:
        raise Exception(f"7adari! {string} kayn fkter mn blassa")
        
        

keywords = ['m²','Pièce','Chambre','bain','an','étage']

Etat = ['Bon état','À rénover','Nouveau']

cols = ['surface','pieces','chambre','bains','age','etage']

def flatten_more(df):
    #parse the column more
    L_more = []

    for row in df.more:
        L_more.append(eval(row))

    # create new list to store values
    surface = []
    pieces = []
    chambre = []
    bains = []
    age = []
    etage = []
    L_index = []

    # c conpliki    
    for elem in L_more:

        index = [index_by_word(key,elem) for key in keywords]
        L_index.append(index)

        #print(index)


    for i,row in enumerate(L_index):

        if row[0] is not None:
            surface.append(L_more[i][row[0]])
        else:
            surface.append(None)



        if row[1] is not None:    
            pieces.append(L_more[i][row[1]])
        else:
            pieces.append(None)




        if row[2] is not None:
            chambre.append(L_more[i][row[2]])
        else:
            chambre.append(None)




        if row[3] is not None:
            bains.append(L_more[i][row[3]])
        else:
            bains.append(None)



        if row[4] is not None:
            age.append(L_more[i][row[4]])
        else:
            age.append(index[4])


        if row[5] is not None:
            etage.append(L_more[i][row[5]])
        else:
            etage.append(None)
            
            
    for col in cols:

        df[col] = eval(col)


    return df

# %%
def eval_2(string):

    if isinstance(string,str):
        return eval(string)
    else:
        return None



def columns_to_numbers(df):
    
    
    df['surface']=df['surface'].apply( lambda x : eval_2(keep_only_digits(x)[:-1] )) #7adari bug hna si surface none
    
    df['pieces']=df['pieces'].apply( lambda x : eval_2(keep_only_digits(x) ))
    
    df['chambre']=df['chambre'].apply( lambda x : eval_2(keep_only_digits(x) ))
    
    
    df['bains']=df['bains'].apply( lambda x : eval_2(keep_only_digits(x) ))
    
    df['etage'] = df['etage'].apply( lambda x : eval_2(keep_only_digits(x) ))
    
    return df



def flatten_carac(df):
    L_carac = []

    for e in df.caracteristiques:
        L_carac.append(eval(e))

    merged = list(itertools.chain(*L_carac))

    unique = list(set(merged))

    unique.remove('')
    
    for var in unique:
        
        L=[]
        
        for row in L_carac:
            if var in row:
                L.append(1)
            else:
                L.append(None)
                
                
        df[var] = L
        
        
    return df

# %%
df['price'] = df['price'].apply( lambda x : price_string_to_float(x))

df['X'] = df['localization'].apply(lambda loc : get_X_Y(loc, axe='X'))

df['Y'] = df['localization'].apply(lambda loc : get_X_Y(loc, axe='Y'))

df['type_link'] = df['offer link'].apply(lambda link : get_type_from_link(link))

df['type_title'] = df['title'].apply(lambda link : get_type_from_link(link))

df['date'] = df['date'].apply(lambda x : string_to_date(x))   

df = flatten_more(df)

df = columns_to_numbers(df)
df = flatten_carac(df)

df['prix/m²'] = round(df['price']/df['surface'],2)

# %%
# bricoul

def istislam(x):
    if isinstance(x,str):
        return x
    else:
        return None
    
df['age'] = df['age'].apply(lambda x : istislam(x))

# %%
len(df.columns)
# Out:
# 48

# %%
df
# Out:
#           date arrondissement  \
# 0   2022-01-04      Bernoussi
# 1   2022-01-04      Bernoussi
# 2   2022-01-04      Bernoussi
# 3   2022-01-04      Bernoussi
# 4   2021-12-31      Bernoussi
# ..         ...            ...
# 674 2021-07-08  Roches-Noires
# 675 2021-07-08  Roches-Noires
# 676 2021-07-08  Roches-Noires
# 677 2021-07-08  Roches-Noires
# 678 2021-07-08  Roches-Noires
#
#                                             offer link  \
# 0    https://www.mubawab.ma/fr/pa/7284467/apartemen...
# 1    https://www.mubawab.ma/fr/pa/7276884/studio-de...
# 2    https://www.mubawab.ma/fr/pa/7276873/apartemen...
# 3    https://www.mubawab.ma/fr/pa/7276874/apartemen...
# 4    https://www.mubawab.ma/fr/pa/7126484/apparteme...
# ..                                                 ...
# 674  https://www.mubawab.ma/fr/a/7046458/vend-appar...
# 675  https://www.mubawab.ma/fr/a/7045710/appartemen...
# 676  https://www.mubawab.ma/fr/a/7044079/appartemen...
# 677  https://www.mubawab.ma/fr/a/6141401/%C3%A0-ven...
# 678  https://www.mubawab.ma/fr/a/6807862/appartemen...
#
#                                                  title      price  \
# 0    Apartement de 75m² en vente, Résidence El Yass...   700000.0
# 1      Studio de 55m² en vente, Résidence El Yassamine   500000.0
# 2    Apartement de 83m² en vente, Résidence El Yass...   795000.0
# 3    Apartement de 79m² en vente, Résidence El Yass...   735000.0
# 4               Appartement de 74m², Résidence Salabel        NaN
# ..                                                 ...        ...
# 674  Vend appartement à Casablanca. 5 grandes pièce...  1300000.0
# 675               Appartement à vendre en centre ville  2300000.0
# 676       Appartement en vente centre ville casablanca   850000.0
# 677               À vendre appartement à bnou tachfine  1180000.0
# 678    Appartement de 120m², au 3ème Etage à Belvédère  1300000.0
#
#                                           localization  \
# 0    {'x': '33.61040882133904', 'y': '-7.4803556856...
# 1    {'x': '33.61040882133904', 'y': '-7.4803556856...
# 2    {'x': '33.61040882133904', 'y': '-7.4803556856...
# 3    {'x': '33.61040882133904', 'y': '-7.4803556856...
# 4    {'x': '33.61726394078692', 'y': '-7.5016450881...
# ..                                                 ...
# 674  {'x': '33.59203600000001', 'y': '-7.5899550999...
# 675  {'x': '33.5895625839363', 'y': '-7.59678840637...
# 676  {'x': '33.5895625839363', 'y': '-7.59678840637...
# 677  {'x': '33.5898485788819', 'y': '-7.59320497512...
# 678  {'x': '33.5895625839363', 'y': '-7.59678840637...
#
#                                            description  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 674  Appartement idéal à la vente. Prix 1 300 000 D...
# 675  Appartement très spacieux avec vue sur jardin ...
# 676  Appartement à vendre de 113m2 situé en face de...
# 677  dans une résidence sécurisée fermée se trouve ...
# 678  Appartement de 120m² au 3ème étage (ancien cab...
#
#                                                   more  \
# 0    ['75 m²', '3 Pièces', '2 Chambres', '1 Salle d...
# 1    ['55 m²', '2 Pièces', '1 Chambre', '1 Salle de...
# 2    ['83 m²', '3 Pièces', '2 Chambres', '1 Salle d...
# 3    ['79 m²', '3 Pièces', '2 Chambres', '1 Salle d...
# 4    ['74 m²', '3 Pièces', '2 Chambres', '2 Salles ...
# ..                                                 ...
# 674  ['116 m²', '5 Pièces', '2 Chambres', '1 Salle ...
# 675  ['180 m²', '5 Pièces', '3 Chambres', '2 Salles...
# 676  ['113 m²', '4 Pièces', '3 Chambres', '2 Salles...
# 677  ['118 m²', '8 Pièces', '3 Chambres', '2 Salles...
# 678  ['120 m²', '3 Pièces', '2 Chambres', '1 Salle ...
#
#                                       caracteristiques                  X  \
# 0    ['Piscine', 'Climatisation', 'Sécurité', 'Cuis...  33.61040882133904
# 1    ['Piscine', 'Climatisation', 'Sécurité', 'Cuis...  33.61040882133904
# 2    ['Piscine', 'Climatisation', 'Sécurité', 'Cuis...  33.61040882133904
# 3    ['Piscine', 'Climatisation', 'Sécurité', 'Cuis...  33.61040882133904
# 4                                         ['Terrasse']  33.61726394078692
# ..                                                 ...                ...
# 674  ['Terrasse', 'Garage', 'Concierge', 'Chambre r...  33.59203600000001
# 675  ['Garage', 'Ascenseur', 'Jardin', 'Chambre ran...   33.5895625839363
# 676                                      ['Ascenseur']   33.5895625839363
# 677  ['Garage', 'Ascenseur', 'Concierge', 'Salon Ma...   33.5898485788819
# 678               ['Garage', 'Ascenseur', 'Carrelage']   33.5895625839363
#
#      ... Parquet Cuisine équipée Salon Marocain  Climatisation  Micro-ondes  \
# 0    ...     NaN             1.0            NaN            1.0          NaN
# 1    ...     NaN             1.0            NaN            1.0          NaN
# 2    ...     NaN             1.0            NaN            1.0          NaN
# 3    ...     NaN             1.0            NaN            1.0          NaN
# 4    ...     NaN             NaN            NaN            NaN          NaN
# ..   ...     ...             ...            ...            ...          ...
# 674  ...     NaN             1.0            1.0            NaN          NaN
# 675  ...     NaN             NaN            1.0            NaN          NaN
# 676  ...     NaN             NaN            NaN            NaN          NaN
# 677  ...     NaN             1.0            1.0            NaN          NaN
# 678  ...     NaN             NaN            NaN            NaN          NaN
#
#      Terrasse  Concierge Ascenseur  Internet   prix/m²
# 0         NaN        NaN       NaN       NaN   9333.33
# 1         NaN        NaN       NaN       NaN   9090.91
# 2         NaN        NaN       NaN       NaN   9578.31
# 3         NaN        NaN       NaN       NaN   9303.80
# 4         1.0        NaN       NaN       NaN       NaN
# ..        ...        ...       ...       ...       ...
# 674       1.0        1.0       NaN       NaN  11206.90
# 675       NaN        NaN       1.0       NaN  12777.78
# 676       NaN        NaN       1.0       NaN   7522.12
# 677       NaN        1.0       1.0       NaN  10000.00
# 678       NaN        NaN       1.0       NaN  10833.33
#
# [679 rows x 48 columns]
